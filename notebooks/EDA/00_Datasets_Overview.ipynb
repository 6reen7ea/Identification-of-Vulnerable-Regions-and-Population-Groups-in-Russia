# %% [markdown]
# # Overview of Project Datasets
#
# This notebook provides a consolidated overview of all datasets used in the project.
#
# It includes:
# - a description of each source dataset
# - key metadata (size, regions, time coverage)
# - main features selected for the master dataset
# - notes on data quality and limitations
#
# This document serves as a foundation for building the master dataset and conducting further analysis.

# %%
import pandas as pd

# %%
df = pd.read_excel("../../data/clean/datasets_overvieww.xlsx")
df
# Out:
#      №                Датасет                                    Файл  Строк  \
# 0    1                poverty                poverty_standardized.csv   2180
# 1    2                 income            real_income_standardized.csv    478
# 2    3                 socdem         poverty_socdem_standardized.csv    336
# 3    4              drug_alco              drug_alco_standardized.csv    696
# 4    5              morbidity              morbidity_standardized.csv  68041
# 5    6                housing                housing_standardized.csv     85
# 6    7                  gross                  gross_standardized.csv   2161
# 7    8             population             population_standardized.csv    505
# 8    9               disabled               disabled_standardized.csv   5434
# 9   10  child_mortality_rural  child_mortality_rural_standardized.csv   2674
# 10  11  child_mortality_urban  child_mortality_urban_standardized.csv   2705
# ...

# %% [markdown]
# ## Conclusion
#
# After reviewing all source datasets, it was decided to focus on the period **2015–2020**.
#
# This time range was selected to:
# - capture the most recent available data
# - minimize missing values across datasets
#
# This approach allows the creation of a unified master dataset with a complete set of features for all regions, which is essential for reliable comparison and clustering.
